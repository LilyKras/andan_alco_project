# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib.pyplot
# %pip install seaborn
# %pip install sklearn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Тема проекта: влияние алкоголя на успеваемость в школе

# %% [markdown]
# https://www.kaggle.com/datasets/whenamancodes/alcohol-effects-on-study?resource=download - ссылка на исследуемый датасет

# %% [markdown]
# Описание:
#
# В данном проекте представлен обзор датасета, содержащего информацию об учениках португальских образовательных учреждений, включая общую информацию об учениках, информацию о их успеваемости в образовательном учреждении и информацию об объемах потребляемого алкоголя. В датасете рассматриваются оценки по математике. Примечательно, что в данных датасетах представлена информация об учниках получающих среднее образование (возраст респондентов 15-22). При этом возраст легализации алкоголя в Португалии (данные представлены именно по этой стране) - 18 лет.
#
#
# Описание переменных представленных в датасете:
#
# School - категориальная переменная, наименование учебного заведения, в котором учится респондент: 'GP' - Gabriel Pereira, 'MS' - Mousinho da Silveira
#
# Sex	- категориальная переменная, пол респондента: 'F' - девушка, 'M' - парень.
#
# Age -  количетсвенная  переменная, возраст респондента: от 15 до 22
#
# Adress - категориальная переменная, тип местности, в которой проживает респондент:  'U' - город, 'R' - сельская местность
#
# Famsize - категориальная переменная, показавыет размер семьи респондента: 'LE3' - 3 человека или меньше, 'GT3' - больше 3 человек
#
# Pstatus - категориальная переменная, семейный статус родителей: 'T' - родители живут вместе, 'A' - родители живут отдельно
#
# Medu - количественная переменная, оразование матери респондента: 0 - нет, 1 - начальное (4 класса), 2 - с 5-го по 9-й класс, 3 - среднее образование, 4 - высшее образование.
#
# Fedu - количественная переменная, образование отца: 0 - нет, 1 - начальное (4 класса), 2 - с 5-го по 9-й класс, 3 - среднее образование, 4 - высшее образование.
#
# Mjob - категориальная переменная, профессия матери: 'teacher' - учитель, 'health' - медицинский работник, 'services' - государственная служба (например, полиция или адмистративная работа), 'at_home' - домохозяйка, 'other' - другое.
#
# Fjob - категориальная переменная, профессия отца: 'teacher' - учитель, 'health' - медицинский работник, 'services' - государственная служба (например, полиция или адмистративная работа), 'at_home' - домохозяин, 'other' - другое.
#
# Reason - категориальная переменная, причина выбора данной школы: 'home' - близость к дому, 'reputation' - репутация школы, 'course' - предпочтение по курсу, 'other' - другое.
#
# Guardian - категориальная переменная, опекун респондента: 'mother' - мать, 'father' - отец, 'other' - другой.
#
# Traveltime - количественная переменная, время в пути от дома до школы: 1 - менее 15 минут, 2 - от 15 до 30 минут, 3 - от 30 минут до 1 часа, 4 - более 1 часа.
#
# Studytime - количественная переменная, время, затрачиваемое на учебу в неделю: 1 - менее 2 часов, 2 - от 2 до 5 часов, 3 - от 5 до 10 часов, 4 - более 10 часов.
#
# Failures - количественная переменная, количество прошлых неудач в учебе (я так понимаю, что не перевли в следующий класс или типа того): n, если 1 <= n < 3, иначе 0.
#
# Schoolsup - категориальная переменная, наличие дополнительных курсов: 'yes' - есть, 'no' - нет.
#
# Famsup - категориальная переменная, наличие образовательной поддержки от семьи: 'yes' - есть, 'no' - нет.
#
# Paid - категориальная переменная, наличие платных дополнительных занятий по предметам: 'yes' - есть, 'no' - нет.
#
# Activities - категориальная переменная, наличие внеклассной деятельности: 'yes' - есть, 'no' - нет.
#
# Nursery - категориальная переменная, посещение детского сада: 'yes' - было, 'no' - нет.
#
# Higher - категориальная переменная, желание получить высшее образование: 'yes' - есть, 'no' - нет.
#
# Internet - категориальная переменная, наличие доступа в интернет дома: 'yes' - есть, 'no' - нет.
#
# Romantic - категориальная переменная, наличие романтических отношений: 'yes' - есть, 'no' - нет.
#
# Famrel - количественная переменная, качество семейных отношений: от 1 до 5, где 1 - очень плохо, до 5 - отлично.
#
# Freetime - количественная переменная, свободное время после школы: от 1 до 5, где 1 - очень мало, до 5 - очень много.
#
# Goout - количественная переменная, времяпрепровождение с друзьями: от 1 до 5, где 1 - очень редко, до 5 - очень часто.
#
# Dalc - количественная переменная, потребление алкоголя в будни: от 1 до 5, где 1 - очень мало, до 5 - очень много.
#
# Walc - количественная переменная, потребление алкоголя в выходные: от 1 до 5, где 1 - очень мало, до 5 - очень много.
#
# Health - количественная переменная, текущее состояние здоровья: от 1 до 5, где 1 - очень плохо, до 5 - очень хорошо.
#
# Absences - количественная переменная, количество пропусков занятий: от 0 до 93.
#
#
# За рассматриваемые предметы ученики получают оцеки (удивительно).
#
# G1 - количественная переменная, оценка за первый период: от 0 до 20
#
# G2 - количественная переменная, оценка за второй период: от 0 до 20
#
# G3 - количественная переменная, итоговая оценка за учебный год, которая выставляется в третьем периоде (триместре), имеет сильную корреляцию с G2 и G1: от 0 до 20

# %% [markdown]
# Начнем с оценок за математику

# %% [markdown]
# ## Работа с датасетом по математике

# %% [markdown]
# ### EDA датасета по математике

# %%
df_math = pd.read_csv('data/Maths.csv')

df_math.shape
# Out:
# (395, 33)

# %%
df_math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Присутствуют как категориальные, так и количественные признаки (количественных всего 3 - ['absences', 'failures', 'age'])

# %%
fig, axs = plt.subplots(11, 3, figsize=(20, 60))
for i in range(len(df_math.columns)):
    
    column = df_math.columns[i]
    c = int(i /3)
    r = int(i%3)

    if df_math[column].dtype == 'object':
        df_math[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.3), ax = axs[c, r])
        axs[c][r].set_title(f'Distribution of {column}')
        axs[c][r].set_ylabel('')
        
    else:
        axs[c, r].hist(df_math[column])
        axs[c][r].set_title(f'Distribution of {column}')
        axs[c][r].set_xlabel(column)
        axs[c][r].set_ylabel('Frequency')

# %% [markdown]
# По признакам school, higher, schoolsup, Pstatus данные не сбалансированы
#
# Имеет смысл убрать столбец с higher потому что почти все планируют получать высшее образование
#
# Остальные могут логически сильно влиять на успеваемость (от школы зависят критерии оценки, от материальной поддержки школы - желание сохранить хорошую оценку и не потерять поддержку, от статуса отношений родителей - если родители живут вместе, то это способствует благоприятному влиянию на психику ребенка, и получается, что оба родителя вместе могут лучше заставлять ребенка учиться (тут возрастающая отдача от масштаба))
#
# Посмотрим на правдивость данных теорий после обучения линейной модели

# %%
del df_math['higher']

# %%
display(df_math.isnull().any().any())
# Out:
# False

# %% [markdown]
# Пропущенных значений нет

# %%
df_math.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
ax = sns.heatmap(df_math.corr(numeric_only=True),annot = True, fmt = ".2f")
for t in ax.texts:
    if float(t.get_text()) >= 0.4 or float(t.get_text()) <= -0.4:
        t.set_text(t.get_text())
    else:
        t.set_text("")
plt.xticks(rotation=90)
plt.yticks(rotation = 0)
ax.set_title('Correlation heatmap', fontdict = {'fontsize':20, 'fontweight':600})

plt.show()

# %% [markdown]
# Заметим, что очень большая корреляция между G3(годовой оценкой) и G1 & G2 (промежуточные), потому что годовая оценка строится из промежуточных, поэтому оставим только годовую оценку (и переименуем ее в Mgrade)

# %%
df_math['Mgrade'] = df_math['G3']
del df_math['G3']
del df_math['G1']
del df_math['G2']

# %% [markdown]
# Так же обратим внимание, что большую корреляцию между собой имеют Dalc и Walc(потребление алкоголя в рабочие и выходные дни)
#
# Объединим эти переменные. Поскольку выходных меньше (2 дня из 7), то умножим значение Walc на 5, Dalc на 2, сложим и сумму разделим на 7 (получим ежедневное потребление алкоголя)
#
# Переменная стала количественной))

# %%
df_math['Alc'] = (df_math['Dalc']*2 + df_math['Walc']*5)/7

# %%
del df_math['Dalc']
del df_math['Walc']

# %%
plt.hist(df_math['Alc'])
plt.title("Distribution of daily alcohol consumption")
plt.xlabel('Daily alcohol consumption')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Обратим внимание, что в основном ученики не пьют

# %% [markdown]
# Еще очень сильно коррелируют Medu и Fedu (скорее всего потому что люди находят себе пару во время обучения, а значит если они поженились, то образование у них одинаковое)

# %% [markdown]
# Осталось закодировать категориальные признаки с помощью OneHot-кодирования

# %%
var_real = ['absences', 'failures', 'age', 'Alc', 'Mgrade']
var_cat = []
for var in df_math.columns:
    if var not in var_real:
        var_cat.append(var)
print(var_cat)
# Out:
# ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'health']

# %%
df_math = pd.get_dummies(df_math, columns = var_cat)

# %% [markdown]
# Наша задача - узнать, как влияет алкоголь на успеваемость в школе(в качестве успеваемости в школе будет использовать оценку по математике Mgrade)
#
# Построим линейную регрессию для предсказания итоговой оценки по курсу математики, до этого посмотрим на корреляцию с другими переменными переменной Mgrade

# %%
plt.hist(df_math['Mgrade'], bins = 20)
plt.title("Distribution of math grade")
plt.xlabel('Math grade')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Есть экстремально низкие значение (оценка около нуля или 0), а так в основном распределение оценок похоже на нормальное

# %%
df_math['Mgrade'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: Mgrade, dtype: float64

# %%
display((df_math.corr()['Mgrade']).sort_values())
# Out:
# failures       -0.360415
# age            -0.161579
# Medu_1         -0.159096
# Fedu_1         -0.140572
# romantic_yes   -0.129970
#                   ...
# health_1        0.117034
# Fedu_4          0.117569
# romantic_no     0.129970
# Medu_4          0.207552
# Mgrade          1.000000
# Name: Mgrade, Length: 84, dtype: float64

# %% [markdown]
# Посмотрим так же облака рассеивания

# %% [markdown]
# Гипотеза: потребление алкоголя никак не влияет на успеваемость в учебе
#
# Гипотеза 2: на успеваемость в школе больше всего положительно влияет высшее образование отца (если он имеет высшее образование, то будет больше добииваться хороших оценок от своего ребенка)
#
# Гипотеза 3: Количество пропусков занятий и возраст ученика отрицательно влияют на успеваемость (реже посещает занятия -> меньше узнает -> хуже оценки, с возрастом  у учеников появляются прочие приритеты, помимо учебы, также возможна интерпретация через повышение сложности материала).

# %% [markdown]
# ### ML датасета по математике

# %% [markdown]
# Для тестирования гипотез применяется именно метод машинного обучения поскольку он в большей степени показывает прично-следственную связь, чем метод обычной корреляции

# %% [markdown]
# Разделим на x и y

# %%
y = df_math['Mgrade']
X = df_math
del X['Mgrade']

# %% [markdown]
# Теперь на test и train

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Используем StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# в рамках метода машинного обучения применяется именно линейная модель поскольку линейные модели хорошо работают при небольших объемах данных. В отличае от сложных моделей, которые могут потребовать больших объемов данных для эффективного обучения, линейная модель может предоставить полезных результат даже при ограниченном объеме данных.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)

y_train_result = linreg.predict(X_train_scaled)
y_test_result = linreg.predict(X_test_scaled)


print(mean_squared_error(y_train, y_train_result)**0.5)
print(mean_squared_error(y_test, y_test_result)**0.5)
# Out:
# 3.5323168738927775
# 4.825470587575081

# %% [markdown]
# Очень высокая ошибка (около четверти от максимального значения 20)

# %%
columns = X.columns
for i in range(len(columns)):
  print(f'{columns[i]}\t\t{linreg.coef_[i]:.2f}')
# Out:
# age		-0.87
# failures		-1.33
# absences		0.23
# Alc		0.09
# school_GP		-116742723130941.89
# school_MS		-116742723130941.58
# sex_F		-106330319344842.70
# sex_M		-106330319344842.19
# address_R		-119975603307944.62
# address_U		-119975603307944.47
# famsize_GT3		-52224429362279.83
# famsize_LE3		-52224429362279.67
# Pstatus_A		-138210022126785.97
# Pstatus_T		-138210022126785.86
# Medu_0		-7465129448833.83
# Medu_1		-30658686195753.35
# Medu_2		-37542974537743.52
# Medu_3		-37925663516538.19
# Medu_4		-42396184649918.96
# Fedu_0		-16772748307675.29
# Fedu_1		-78448983009253.91
# Fedu_2		-89719527950566.17
# Fedu_3		-85629551404168.31
# Fedu_4		-86441054382079.62
# Mjob_at_home		-37893587117088.01
# Mjob_health		-35055689054359.82
# Mjob_other		-57684371296722.05
# Mjob_services		-53161028462465.26
# Mjob_teacher		-44331668448213.94
# Fjob_at_home		18577290309948.29
# Fjob_health		21288077704709.43
# Fjob_other		45067070511393.31
# Fjob_services		39634411279410.30
# ...

# %% [markdown]
# Высокие коэффициенты говорят о том, что модель переобучилась

# %% [markdown]
# Попробуем использовать Lasso регрессию, чтобы избежать переобучения.

# %%
from sklearn.linear_model import Lasso

l = Lasso(alpha=40)
l.fit(X_train_scaled, y_train)


print(mean_squared_error(y_train, l.predict(X_train_scaled))**0.5)
print(mean_squared_error(y_test, l.predict(X_test_scaled))**0.5)
# Out:
# 4.464419477697167
# 4.826883346292495

# %%
columns = X.columns
for i in range(len(columns)):
  print(f'{columns[i]}\t\t{l.coef_[i]:.2f}')

print(len(columns))
# Out:
# age		-0.00
# failures		-0.00
# absences		0.00
# Alc		-0.00
# school_GP		0.00
# school_MS		-0.00
# sex_F		-0.00
# sex_M		0.00
# address_R		-0.00
# address_U		0.00
# famsize_GT3		-0.00
# famsize_LE3		0.00
# Pstatus_A		0.00
# Pstatus_T		-0.00
# Medu_0		0.00
# Medu_1		-0.00
# Medu_2		-0.00
# Medu_3		-0.00
# Medu_4		0.00
# Fedu_0		0.00
# Fedu_1		-0.00
# Fedu_2		-0.00
# Fedu_3		0.00
# Fedu_4		0.00
# Mjob_at_home		-0.00
# Mjob_health		0.00
# Mjob_other		-0.00
# Mjob_services		0.00
# Mjob_teacher		-0.00
# Fjob_at_home		-0.00
# Fjob_health		0.00
# Fjob_other		-0.00
# Fjob_services		-0.00
# Fjob_teacher		0.00
# reason_course		-0.00
# reason_home		-0.00
# reason_other		0.00
# reason_reputation		0.00
# guardian_father		-0.00
# guardian_mother		0.00
# guardian_other		-0.00
# traveltime_1		0.00
# traveltime_2		-0.00
# traveltime_3		0.00
# traveltime_4		0.00
# studytime_1		-0.00
# studytime_2		-0.00
# studytime_3		0.00
# studytime_4		0.00
# schoolsup_no		0.00
# schoolsup_yes		-0.00
# ...

# %%
count = 0
for i in range(len(X.columns)):
  if (l.coef_[i] == 0):
    count += 1
    print(X.columns[i], l.coef_[i], sep = '\t')


print(count)
# Out:
# age	-0.0
# failures	-0.0
# absences	0.0
# Alc	-0.0
# school_GP	0.0
# school_MS	-0.0
# sex_F	-0.0
# sex_M	0.0
# address_R	-0.0
# address_U	0.0
# famsize_GT3	-0.0
# famsize_LE3	0.0
# Pstatus_A	0.0
# Pstatus_T	-0.0
# Medu_0	0.0
# Medu_1	-0.0
# Medu_2	-0.0
# Medu_3	-0.0
# Medu_4	0.0
# Fedu_0	0.0
# Fedu_1	-0.0
# Fedu_2	-0.0
# Fedu_3	0.0
# Fedu_4	0.0
# Mjob_at_home	-0.0
# Mjob_health	0.0
# Mjob_other	-0.0
# Mjob_services	0.0
# Mjob_teacher	-0.0
# Fjob_at_home	-0.0
# Fjob_health	0.0
# Fjob_other	-0.0
# Fjob_services	-0.0
# Fjob_teacher	0.0
# reason_course	-0.0
# reason_home	-0.0
# reason_other	0.0
# reason_reputation	0.0
# guardian_father	-0.0
# guardian_mother	0.0
# guardian_other	-0.0
# traveltime_1	0.0
# traveltime_2	-0.0
# traveltime_3	0.0
# traveltime_4	0.0
# studytime_1	-0.0
# studytime_2	-0.0
# studytime_3	0.0
# studytime_4	0.0
# schoolsup_no	0.0
# schoolsup_yes	-0.0
# famsup_no	0.0
# famsup_yes	-0.0
# paid_no	-0.0
# paid_yes	0.0
# activities_no	-0.0
# activities_yes	0.0
# ...

# %% [markdown]
# Попробуем подобрать альфу, а то пока все коэффициенты у нас занулились)))

# %%
from sklearn.model_selection import GridSearchCV

# %%
gsl = GridSearchCV(Lasso(max_iter=250000), {'alpha': np.arange(0.5, 20, 1)}, cv=5, scoring='neg_mean_squared_error')

gsl.fit(X_train_scaled, y_train)

print(gsl.best_params_['alpha'])
# Out:
# 0.5

# %%
from sklearn.linear_model import Lasso

l = Lasso(alpha=0.5)
l.fit(X_train_scaled, y_train)


print(mean_squared_error(y_train, l.predict(X_train_scaled))**0.5)
print(mean_squared_error(y_test, l.predict(X_test_scaled))**0.5)
# Out:
# 4.068209945150513
# 4.592690686241434

# %% [markdown]
# Стало получше на тестовой выборке и похуже на обучающейся, но все равно плохо

# %%
columns = X.columns
for i in range(len(columns)):
  print(f'{columns[i]}\t\t{l.coef_[i]:.2f}')
# Out:
# age		-0.11
# failures		-1.28
# absences		0.00
# Alc		-0.00
# school_GP		0.00
# school_MS		-0.00
# sex_F		-0.00
# sex_M		0.00
# address_R		-0.00
# address_U		0.00
# famsize_GT3		-0.00
# famsize_LE3		0.00
# Pstatus_A		0.00
# Pstatus_T		-0.00
# Medu_0		0.00
# Medu_1		-0.00
# Medu_2		-0.00
# Medu_3		-0.00
# Medu_4		0.00
# Fedu_0		0.00
# Fedu_1		-0.00
# Fedu_2		-0.00
# Fedu_3		-0.00
# Fedu_4		0.00
# Mjob_at_home		-0.00
# Mjob_health		0.00
# Mjob_other		-0.02
# Mjob_services		0.07
# Mjob_teacher		-0.00
# Fjob_at_home		0.00
# Fjob_health		0.00
# Fjob_other		-0.00
# Fjob_services		-0.00
# Fjob_teacher		0.00
# reason_course		-0.00
# reason_home		-0.00
# reason_other		0.00
# reason_reputation		0.00
# guardian_father		-0.00
# guardian_mother		0.00
# guardian_other		0.00
# traveltime_1		0.00
# traveltime_2		-0.00
# traveltime_3		0.00
# traveltime_4		0.00
# studytime_1		-0.00
# studytime_2		-0.00
# studytime_3		0.03
# studytime_4		0.00
# schoolsup_no		0.12
# schoolsup_yes		-0.00
# ...

# %%
for i in range(len(X.columns)):
  if (l.coef_[i] != 0): 
    count += 1
    print(X.columns[i], l.coef_[i], sep = '\t')
# Out:
# age	-0.1093495124698376
# failures	-1.280622711347203
# Mjob_other	-0.021676194193555105
# Mjob_services	0.07332483210752648
# studytime_3	0.026357356650522867
# schoolsup_no	0.11591915646592205
# schoolsup_yes	-1.0297720808117397e-16
# freetime_2	0.003035224512611375
# freetime_3	-0.05461886468016067

# %% [markdown]
# Коэфициенты перестали быть огромыми, а значит переобучения нет
#
# Скорее всего проблема в малом количестве данных

# %% [markdown]
# Гипотеза 3 (про отрицательное) влияние количества пропусков и возраста подтвердиласью
#
# Остальные переменные практические не влияют.
#
# Гипотеза 1: (про влияние алкоголя на успеваемость) не подтвердилась
#
# Гипотеза 2: (про образование отца) не подтвеардилась
